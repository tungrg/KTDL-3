# %% [markdown]
# # Lab03 - Clustering

# %% [markdown]
# ## Yêu cầu bài tập
#
# **Cách làm bài**
#
#
# - Bạn sẽ làm trực tiếp trên file notebook này; trong file, từ `TODO` để cho biết những phần mà bạn cần phải làm. **Không được sửa những chỗ không có** `TODO`.
#
# - Bạn có thể thảo luận ý tưởng cũng như tham khảo các tài liệu, nhưng *code và bài làm phải là của bạn*.
#
# - Nếu vi phạm thì sẽ bị 0 điểm cho bài tập này.
#
# - Trước khi nộp bài, rerun lại notebook (`Kernel` -> `Restart & Run All`) và ấn Ctrl+S để lưu lại.
#
# **Nội dung bài tập**
#
# Trong bài này, bạn sẽ cài đặt 2 thuật toán `k-means` và `k-medois` để gom nhóm dữ liệu.

# %% [markdown]
# ## Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Cài đặt thuật toán K-mean

# %% [markdown]
# Tính khoảng cách euclid giữa 2 điểm dữ liệu x, y

# %%
def euclidianDistance(x, y):
    '''
    Euclidian distance between x, y
    --------
    Return
    d: float
    '''
    #TODO
    dist = np.linalg.norm(x-y)
    return dist

# %%
class k_means:
    def __init__(self, k=2, thresold = 0.001, max_iter = 300, has_converged=False):
      
        ''' 
        Class constructor
        
        Parameters
        ----------
        - k: number of clusters. 
        - thresold (percentage): stop algorithm when difference between prev cluster 
                                 and new cluster is less than thresold
        - max_iter: number of times centroids will move
        - has_converged: to check if the algorithm stop or not
        '''

 
        self.k = k
        self.thresold = thresold
        self.max_iter = max_iter
        self.has_converged= has_converged
        
    def initCentroids(self, X):
        ''' 
        Parameters
        ----------
        X: input data. 
        '''
        self.centroids=[]
        
        #Starting clusters will be random members from X set
        indexes = np.random.randint(0, len(X)-1, self.k)
        self.centroids=X[indexes]
            
        
    def updateCentroids(self, cur_centroids):
        '''
        Class constructor
        
        Parameters
        ----------
        cur_centroids: list of new centroids
        
        '''
        self.has_converged=True
        
        for c in range(0,self.k):
            prev_centroid = self.centroids[c]
            cur_centroid  = cur_centroids[c]
            #checking if % of difference between old position and new position is more than thresold
            
            #TODO d=?
            d = euclidianDistance(prev_centroid, cur_centroid)
            
            
            if  d > self.thresold:
                self.has_converged = False
                self.centroids = cur_centroids
            
    def fit(self, X):
        '''
        FIT function, used to find clusters
    
        Parameters
        ----------
        X: input data. 
        '''
        #Init list cluster centroids
        self.initCentroids(X)
        #Main loop
        for i in range(self.max_iter):  
            #Centroids for this iteration
            cur_centroids = []
            for centroid in range(0,self.k):
                #List samples of current cluster
                samples = []
                
                for k in range(len(X)):
                    d_list = []
                    for j in range(self.k):
                        d_list.append(euclidianDistance(self.centroids[j], X[k]))
                    
                    # Cluster has minimal distance between its centroid and data sample
                    # TODO (c=???)
                    min_distance = min(d_list)
                    for index in range(len(d_list)):
                        if d_list[index] == min_distance:
                            c = index
                            break                        
                    #Store sample to list
                    if c == centroid:
                        samples.append(X[k])   
                #New centroids of each cluster is calculated by mean of all samples closest to it
                
                #TODO (new_centroid=???)
                a = np.array(samples)
                new_centroid = np.mean(a,axis = 0)
                
                cur_centroids.append(new_centroid)
            self.updateCentroids(cur_centroids)
            
            if self.has_converged:
                break
        
        #Each cluster represented by its centroid
        return np.array(self.centroids)

    def predict(self, data):
        ''' 
        Parameters
        ----------
        data: input data.
        
        Returns:
        ----------
        pred: list cluster indexes of input data 
        '''
    
        pred = []
        for i in range(len(data)):
            # Create list distances between centroids and data sample
            d_list = []
            for j in range(len(self.centroids)):
                
                # Calculate distances between current data sample and centroid(using euclidian distance) 
                # Store to d_list
                #TODO 
                d_list.append(euclidianDistance(self.centroids[j], data[i]))        
            # Store the Cluster has minimal distance between its centroid and current data sample to pred
            #TODO 
            temp = np.min(d_list)
            for index in range(len(self.centroids)):
                if d_list[index] == temp:
                    pred.append(index)
                    break                           
        return np.array(pred)

# %% [markdown]
# ## Chạy thuật toán

# %% [markdown]
# **Khởi tạo dữ liệu**

# %% [markdown]
# Ta tạo dữ liệu bằng cách lấy các điểm theo phân phối chuẩn có kỳ vọng tại các điểm có tọa độ (2, 2), (8, 3) và (3, 6), ma trận hiệp phương sai giống nhau và là ma trận đơn vị. Mỗi cluster có 500 điểm. (Chú ý rằng mỗi điểm dữ liệu là một hàng của ma trận dữ liệu.

# %%
np.random.seed(8) # This will fix the randomization; so, you and me will have the same results

means = [[2, 2], [8, 3], [3, 6]]
cov = [[1, 0], [0, 1]]
N = 500
X0 = np.random.multivariate_normal(means[0], cov, N)
X1 = np.random.multivariate_normal(means[1], cov, N)
X2 = np.random.multivariate_normal(means[2], cov, N)

X = np.concatenate((X0, X1, X2), axis = 0)
K = 3

original_label = np.asarray([0]*N + [1]*N + [2]*N).T

# %% [markdown]
# **Hiển thị dữ liệu trên đồ thị**

# %%
def visualize(X, label):
    K = np.amax(label) + 1
    X0 = X[label == 0, :]
    X1 = X[label == 1, :]
    X2 = X[label == 2, :]
    
    #you can fix this dpi 
    plt.figure(dpi=120)
    
    plt.plot(X0[:, 0], X0[:, 1], 'b^', markersize = 4, alpha = .8)
    plt.plot(X1[:, 0], X1[:, 1], 'go', markersize = 4, alpha = .8)
    plt.plot(X2[:, 0], X2[:, 1], 'rs', markersize = 4, alpha = .8)

    plt.axis('equal')
    plt.plot()
    plt.show()
    
visualize(X, original_label)

# %% [markdown]
# **Gom nhóm dữ liệu bằng thuật toán k-means mà bạn vừa cài đặt**

# %%
model1=k_means(k=3)
print('Centers found by your model:')
print(model1.fit(X))

pred=model1.predict(X)

visualize(X,pred)
# Out:
# Centers found by your model:
# [[2.01380571 2.02688416]
#  [8.02344787 3.061206  ]
#  [3.01440769 5.96971345]]

# %% [markdown]
# **Thử lại kết quả với scikit learn**

# %%
from sklearn.cluster import KMeans
model2 = KMeans(n_clusters=3, random_state=0).fit(X)
print('Centers found by scikit-learn:')
print(model2.cluster_centers_)
pred_label = model2.predict(X)
visualize(X, pred_label)
# Out:
# Centers found by scikit-learn:
# [[2.01380571 2.02688416]
#  [8.02344787 3.061206  ]
#  [3.01440769 5.96971345]]

# %% [markdown]
# ## 2. Cài đặt thuật toán K-medoids

# %% [markdown]
# Các bạn cài đặt và thử nghiệm thuật toán K-medois tương tự như phần 1

# %%
def calculateCostDistance(list, point_center):
    list = np.array(list)
    point_center = np.array(point_center)
    total_cost = 0
    for point in list:
        total_cost += euclidianDistance(point, point_center)
    return total_cost

# %%
import random
class k_mediods:
    def __init__(self, k=2, thresold = 0.001, max_iter = 300, has_converged=False):
      
        ''' 
        Class constructor
        
        Parameters
        ----------
        - k: number of clusters. 
        - thresold (percentage): stop algorithm when difference between prev cluster 
                                 and new cluster is less than thresold
        - max_iter: number of times centroids will move
        - has_converged: to check if the algorithm stop or not
        '''

 
        self.k = k
        self.thresold = thresold
        self.max_iter = max_iter
        self.has_converged= has_converged
        
    def initCentroids(self, X):
        ''' 
        Parameters
        ----------
        X: input data. 
        '''
        self.centroids=[]
        
        #Starting clusters will be random members from X set
        indexes = np.random.randint(0, len(X)-1,self.k)
        self.centroids=X[indexes]
            
        
    def updateCentroids(self, cur_centroids):
        '''
        Class constructor
        
        Parameters
        ----------
        cur_centroids: list of new centroids
        
        '''
        self.has_converged=True
        
        for c in range(0,self.k):
            prev_centroid = self.centroids[c]
            cur_centroid  = cur_centroids[c]
            #checking if % of difference between old position and new position is more than thresold
            
            #TODO d=?
            d = euclidianDistance(prev_centroid, cur_centroid)
            
            
            if  d > self.thresold:
                self.has_converged = False
                self.centroids = cur_centroids
            
    def fit(self, X):
        '''
        FIT function, used to find clusters
    
        Parameters
        ----------
        X: input data. 
        '''
        #Init list cluster centroids
        self.initCentroids(X)
        #Main loop
        for i in range(self.max_iter):  
            #Centroids for this iteration
            cur_centroids = []
            for centroid in range(0,self.k):
                #List samples of current cluster
                samples = []
                
                for k in range(len(X)):
                    d_list = []
                    for j in range(self.k):
                        d_list.append(euclidianDistance(self.centroids[j], X[k]))
                    
                    # Cluster has minimal distance between its centroid and data sample
                    # TODO (c=???)
                    min_distance = min(d_list)
                    for index in range(len(d_list)):
                        if d_list[index] == min_distance:
                            c = index
                            break                        
                    #Store sample to list
                    if c == centroid:
                        samples.append(X[k])   
                #New centroids of each cluster is calculated by mean of all samples closest to it
                
                #TODO (new_centroid=???)
                count = 0
                before_cost = calculateCostDistance(samples,self.centroids[centroid])
                array_random = random.sample(range(len(samples)),len(samples))
                for index in range(len(samples)):
                    after_cost = calculateCostDistance(samples,samples[array_random[index]])
                    if after_cost < before_cost:
                        count+= 1
                        cur_centroids.append(samples[array_random[index]])
                        break
                if count ==0:
                    cur_centroids.append(self.centroids[centroid])
            #####
            self.updateCentroids(cur_centroids)
            
            if self.has_converged:
                break
        
        #Each cluster represented by its centroid
        return np.array(self.centroids)
    def predict(self, data):
        ''' 
        Parameters
        ----------
        data: input data.
        
        Returns:
        ----------
        pred: list cluster indexes of input data 
        '''
    
        pred = []
        for i in range(len(data)):
            # Create list distances between centroids and data sample
            d_list = []
            for j in range(len(self.centroids)):
                
                # Calculate distances between current data sample and centroid(using euclidian distance) 
                # Store to d_list
                #TODO 
                d_list.append(euclidianDistance(self.centroids[j], data[i]))        
            # Store the Cluster has minimal distance between its centroid and current data sample to pred
            #TODO 
            temp = np.min(d_list)
            for index in range(len(self.centroids)):
                if d_list[index] == temp:
                    pred.append(index)
                    break                           
        return np.array(pred)

# %%
np.random.seed(8) # This will fix the randomization; so, you and me will have the same results

means = [[2, 2], [8, 3], [3, 6]]
cov = [[1, 0], [0, 1]]
N = 500
X0 = np.random.multivariate_normal(means[0], cov, N)
X1 = np.random.multivariate_normal(means[1], cov, N)
X2 = np.random.multivariate_normal(means[2], cov, N)

X = np.concatenate((X0, X1, X2), axis = 0)
K = 3

original_label = np.asarray([0]*N + [1]*N + [2]*N).T

# %%
model3 = k_mediods(k=3)
print('Centers found by your model:')
print(model3.fit(X))
pred=model3.predict(X)
visualize(X,pred)
# Out:
# Centers found by your model:
# [[1.98413249 2.04159709]
#  [7.93224207 3.0213355 ]
#  [2.98493437 5.97312308]]

# %% [markdown]
# **Thử lại kết quả với scikit learn**

# %%
from sklearn_extra.cluster import KMedoids
model4 = KMedoids(n_clusters=3, random_state=0).fit(X)
print('Centers found by scikit-learn:')
print(model4.cluster_centers_)
pred_label = model4.predict(X)
visualize(X, pred_label)
# Out:
# Centers found by scikit-learn:
# [[1.98413249 2.04159709]
#  [7.93224207 3.0213355 ]
#  [2.98493437 5.97312308]]

# %% [markdown]
# **Nêu điểm khác biệt giữa thuật toán K-means và K-medoids:**
#
# TODO:
#
# **Phương pháp k-mean:** dựa trên các kỹ thuật centroid để đại diện cho cụm và nó nhạy cảm với các ngoại lệ.
#  - Một đối tượng dữ liệu có giá trị cực lớn có thể làm gián đoạn việc phân phối dữ liệu(làm thay đổi phân phối dữ liệu --> Ảnh hưởng đến phương sai).
#  - Không thích hợp đối với các cụm có dạng nồi hay các cụm có kích thước khác nhau.
#
# **Phương pháp k-mediods:** được sử dụng để khắc phục vấn đề, phương pháp K-medoids dựa trên kỹ thuật đối tượng đại diện. Medoid được thay thế bằng centroid để đại diện cho cụm.
#  - Medoid là đối tượng dữ liệu nằm ở trung tâm nhất trong một cụm. Ở đây, k đối tượng dữ liệu được chọn ngẫu nhiên dưới dạng medoid để đại diện cho k cụm và còn lại tất cả các đối tượng dữ liệu được đặt trong một cụm có medoid gần nhất (hoặc tương tự nhất) với đối tượng dữ liệu đó.
#  - Sau khi xử lý tất cả các đối tượng dữ liệu, medoid mới được xác định có thể đại diện cho cụm theo cách tốt hơn và toàn bộ quá trình được lặp lại. Một lần nữa, tất cả các đối tượng dữ liệu được liên kết với các cụm dựa trên các medoid mới.
#  - Trong mỗi lần lặp lại, các medoid thay đổi vị trí của chúng từng bước. Quá trình này được tiếp tục cho đến khi không có bất kỳ động thái nào của medoid. Kết quả là, k cụm được tìm thấy đại diện cho tập hợp n đối tượng dữ liệu.

# %% [markdown]
# # 3. Sử dụng thuật toán gom cụm trên tập dữ liệu Iris

# %%
from sklearn import datasets
iris = datasets.load_iris()

# %%
X = iris.data
y = iris.target

# %%
#Visualizing data
fig, axes = plt.subplots(1, 2, figsize=(14,6),dpi=100)
axes[0].scatter(X[:,0], X[:,1], c=y)
axes[0].set_xlabel('Sepal Length')
axes[0].set_ylabel('Sepal Width')
axes[1].scatter(X[:,2], X[:,3], c=y)
axes[1].set_xlabel('Petal Length')
axes[1].set_ylabel('Pepal Width')
# Out:
# Text(0, 0.5, 'Pepal Width')

# %% [markdown]
# **Nhận xét:**
#
# TODO:
#
# - Petal length and width có sự khác nhau đáng kể (khi so sánh với sepal length, width).
#
# --> Pental có thể được sử dụng cho mục đích phân lớp (classification) và gom cụm (clustering).
#
# **Theo quan sát:** Setosa(màu tím),Versicolor( màu xanh), Virginica (màu vàng).
# - Có thể thấy một cụm Setosa (màu tím) nằm riêng biệt rõ ràng trong khi có rất ít giá trị trùng lặp trong trường hợp Versiclor và Virginica.

# %%
D=X[:,2:]
model=k_means(k=3)
centers = model.fit(D)
print(centers)
# Out:
# [[5.59583333 2.0375    ]
#  [4.26923077 1.34230769]
#  [1.462      0.246     ]]

# %%
new_labels = model.predict(D)
# Plot the identified clusters and compare with the answers
fig, axes = plt.subplots(1, 2, figsize=(14,6),dpi=100)
axes[0].scatter(D[:, 0], D[:, 1], c=y, cmap='gist_rainbow',
edgecolor='k')
axes[1].scatter(D[:, 0], D[:, 1], c=new_labels, cmap='jet',
edgecolor='k')
axes[0].set_xlabel('Petal length')
axes[0].set_ylabel('Petal width')
axes[1].set_xlabel('Petal length')
axes[1].set_ylabel('Petal width')
axes[0].set_title('Actual')
axes[1].set_title('Predicted')
# Out:
# Text(0.5, 1.0, 'Predicted')

# %% [markdown]
# **Nhận xét kết quả:**
#
# TODO:
#
# **Theo quan sát trên thực tế:** Setosa(màu đỏ),Versicolor( màu xanh), Virginica (màu hồng).
# - Ta nhận thấy pental width của Setosa có ít phương sai hơn với một vài ngoại lệ, trong khi Virginica và Versicolor có nhiều phương sai hơn và có một vài giá trị trùng lặp của pental width.
# - Phương sai giữa các giá trị của pental length ít hơn trong trường hợp Setosa so với Virginica và Versicolor. Ngoài ra còn có các giá trị trùng lặp của pental length trong trường hợp Versicolor và Virginica, do đó pental length không phải là một ứng cử viên tốt để sử dụng làm bộ phân loại để phân loại giữa Virginica và Versicolor.

# %% [markdown]
# ### Thực hiện tương tự với thuật toán K-medois

# %%
#TODO
D=X[:,2:]
model=k_mediods(k=3)
centers = model.fit(D)
print(centers)
# Out:
# [[4.4 1.4]
#  [1.4 0.2]
#  [5.6 2.1]]

# %%
new_labels = model.predict(D)
# Plot the identified clusters and compare with the answers
fig, axes = plt.subplots(1, 2, figsize=(14,6),dpi=100)
axes[0].scatter(D[:, 0], D[:, 1], c=y, cmap='gist_rainbow',
edgecolor='k')
axes[1].scatter(D[:, 0], D[:, 1], c=new_labels, cmap='jet',
edgecolor='k')
axes[0].set_xlabel('Petal length')
axes[0].set_ylabel('Petal width')
axes[1].set_xlabel('Petal length')
axes[1].set_ylabel('Petal width')
axes[0].set_title('Actual')
axes[1].set_title('Predicted')
# Out:
# Text(0.5, 1.0, 'Predicted')

# %% [markdown]
# **Nhận xét kết quả:**
#
# TODO:
#
# **Theo quan sát trên thực tế:** Setosa(màu đỏ), Versicolor( màu xanh), Virginica (màu hồng).
# - Phương sai giữa các giá trị của Virginica và Versicolor theo phương pháp kMediods ít hơn các giá trị của Virginica và Versicolor theo phương pháp kMean.
